# %%
angka=float(input("Jari-Jari Lingkaran ="))
pi=22/7
luas_lingkaran=(f'{pi*(angka**2):.2f}')
print("Luas lingkaran dengan jari-jari",angka,"cm adalah",luas_lingkaran,"cm\u00b2")
# Out:
# Jari-Jari Lingkaran = 10
# Luas lingkaran dengan jari-jari 10.0 cm adalah 314.29 cm²
